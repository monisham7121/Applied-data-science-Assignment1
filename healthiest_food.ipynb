# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#importing dataset
df = pd.read_csv(r"C:\Users\Home\OneDrive - University of Hertfordshire\Desktop\Top 100 Healthiest Food in the World.csv")
df_short=df.head(10)
df_short
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 #importing dataset
# ----> 2 df = pd.read_csv(r"C:\Users\Home\OneDrive - University of Hertfordshire\Desktop\Top 100 Healthiest Food in the World.csv")
#       3 df_short=df.head(10)
#       4 df_short
#
# NameError: name 'pd' is not defined

# %%
#finding null values
df_dropped = df_short.dropna()
df_dropped.isnull().sum()
# Out:
# Food                          0
# Nutrition Value (per 100g)    0
# Quantity                      0
# Originated From               0
# Calories                      0
# Protein (g)                   0
# Fiber (g)                     0
# Vitamin C (mg)                0
# Antioxidant Score             0
# dtype: int64

# %%
df.describe()
# Out:
#          Calories  Protein (g)  Fiber (g)  Vitamin C (mg)  Antioxidant Score
# count   98.000000    98.000000  98.000000       98.000000          98.000000
# mean    83.479592     4.361224   3.030612       20.493878        6107.459184
# std     75.609718     5.914331   3.375149       34.704710       18831.230553
# min      1.000000     0.000000   0.000000        0.000000           0.000000
# 25%     19.250000     0.825000   0.850000        0.125000         989.000000
# 50%     61.000000     1.600000   2.150000        5.750000        1540.000000
# 75%    135.500000     4.925000   3.500000       22.275000        4277.250000
# max    320.000000    22.700000  15.600000      190.000000      131420.000000

# %%
numcol=df_short.select_dtypes(include=[np.number])
numcol.corr()
# Out:
#                    Calories  Protein (g)  Fiber (g)  Vitamin C (mg)  \
# Calories           1.000000     0.554850   0.689500       -0.522917
# Protein (g)        0.554850     1.000000   0.241741       -0.349428
# Fiber (g)          0.689500     0.241741   1.000000       -0.196728
# Vitamin C (mg)    -0.522917    -0.349428  -0.196728        1.000000
# Antioxidant Score -0.094182    -0.143822   0.227487       -0.342378
#
#                    Antioxidant Score
# Calories                   -0.094182
# Protein (g)                -0.143822
# Fiber (g)                   0.227487
# Vitamin C (mg)             -0.342378
# Antioxidant Score           1.000000

# %%
# 1. Bar Chart: Distribution of Calories
def plot_bar_chart_calories(df):
    plt.figure(figsize=(10, 4))
    plt.bar(df_short['Food'],df_short['Calories'], color='skyblue', edgecolor='black')
    plt.title("Distribution of Caloric Content")
    plt.xlabel("Food")
    plt.ylabel("Caloric content")
    plt.xticks(rotation=90)
    plt.show()
plot_bar_chart_calories(df)

# %%
# Data from the dataset
foods=df_short['Food']
protein=df_short['Protein (g)']
#print(foods)
def plot_pie_chart(protein, labels, title):

    plt.figure(figsize=(8, 8))
    plt.pie(protein, labels=labels, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
    plt.title(title)
    plt.show()

# Plotting the pie chart for Total Protein Distribution by Food
plot_pie_chart(protein, foods, "Total Protein Distribution by Food")

# %%
# 2. Scatter Plot: Calories vs Fiber
def plot_scatter_protein_fat(df):
    df=df.head(10)
    plt.figure(figsize=(8,4))
    plt.scatter(df_short['Calories'],df_short['Fiber (g)'], color='purple', alpha=0.7)
    plt.title("Food vs Quantity")
    plt.xlabel("Calories")
    plt.ylabel("Fiber (g)")
    plt.show()
plot_scatter_protein_fat(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 10
#       8     plt.ylabel("Fiber (g)")
#       9     plt.show()
# ---> 10 plot_scatter_protein_fat(df)
#
# NameError: name 'df' is not defined

# %%
def plot_heatmap(df):
    df=df.head(25)
    numcol=df.select_dtypes(include=[np.number])
    hmap=numcol.corr()
  
    plt.figure(figsize=(8,6))
    sns.heatmap(hmap,annot=True,cmap='Spectral',linewidth=0.5)
    plt.title('Corelation')
    plt.subplots_adjust(left=0.2,right=0.9,top=0.50,bottom=0.1)
    plt.show()
plot_heatmap(df)
