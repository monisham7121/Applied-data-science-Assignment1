# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#importing dataset
df = pd.read_csv(r"Top 100 Healthiest Food in the World.csv")
df_short=df.head(25)
df_short
# Out:
#             Food      Nutrition Value (per 100g)          Quantity  \
# 0           Kale        High in Vitamins A, C, K    1 cup, chopped
# 1    Blueberries            High in Antioxidants             1 cup
# 2         Salmon     Rich in Omega-3 Fatty Acids              3 oz
# 3         Garlic                Contains Allicin           1 clove
# 4        Spinach         High in Iron and Folate        1 cup, raw
# 5        Almonds        Good Source of Vitamin E    1 oz (23 nuts)
# 6       Broccoli         High in Vitamin C and K    1 cup, chopped
# 7        Avocado            Rich in Healthy Fats          1 medium
# 8         Quinoa         Complete Protein Source     1 cup, cooked
# 9        Lentils       High in Protein and Fiber     1 cup, cooked
# 10  Sweet Potato           Rich in Beta-Carotene          1 medium
# 11     Green Tea               High in Catechins     1 cup, brewed
# 12      Turmeric               Contains Curcumin     1 tsp, ground
# 13          Eggs         Complete Protein Source           1 large
# 14    Chia Seeds       High in Omega-3 and Fiber              1 oz
# 15  Greek Yogurt  High in Protein and Probiotics              6 oz
# 16   Pomegranate            Rich in Antioxidants          1 medium
# 17       Walnuts          Good Source of Omega-3  1 oz (14 halves)
# 18        Ginger    Anti-inflammatory Properties    1 tbsp, grated
# 19     Olive Oil    Rich in Monounsaturated Fats            1 tbsp
# 20         Beets                High in Nitrates        1 cup, raw
# 21      Sardines   Rich in Omega-3 and Vitamin D   3.75 oz, canned
# 22     Mushrooms         Good Source of Selenium        1 cup, raw
# 23      Tomatoes                High in Lycopene          1 medium
# 24          Oats             Rich in Beta-Glucan     1 cup, cooked
#
#           Originated From  Calories  Protein (g)  Fibre (g)  Vitamin C (mg)  \
# 0          Ancient Greece        49          4.3        3.6            93.4
# 1           North America        84          1.1        3.6            14.4
# 2     North Pacific Ocean       208         22.1        0.0             0.0
# 3            Central Asia         4          0.2        0.1             0.9
# 4          Ancient Persia        23          2.9        2.2            28.1
# 5             Middle East       164          6.0        3.5             0.0
# 6                   Italy        31          2.5        2.4            81.2
# 7         Central America       320          4.0       13.5            10.0
# 8           South America       222          8.1        5.2             0.0
# 9             Middle East       230         17.9       15.6             2.1
# 10  Central/South America       103          2.3        3.8            22.3
# 11                  China         2          0.5        0.0             0.0
# 12                  India         9          0.3        0.7             0.5
# 13              Worldwide        72          6.3        0.0             0.0
# 14        Central America       138          4.7       10.6             0.1
# 15                 Greece       100         17.3        0.0             0.0
# 16            Middle East       234          4.7       11.3            28.8
# 17         Ancient Persia       185          4.3        1.9             0.4
# 18         Southeast Asia         4          0.1        0.2             0.7
# 19   Mediterranean Region       119          0.0        0.0             0.0
# 20   Mediterranean Region        58          2.2        3.8             6.7
# 21      Mediterranean Sea       191         22.7        0.0             0.0
# 22              Worldwide        15          2.2        1.0             2.8
# 23          South America        22          1.1        1.5            15.6
# 24                 Europe       166          5.9        4.0             0.0
#
#     Antioxidant Score
# 0                1770
# 1                9621
# 2                 689
# 3                5708
# 4                1515
# 5                4454
# 6                1510
# 7                1922
# 8                1808
# 9                7282
# 10              14187
# 11               1253
# 12             127068
# 13                705
# 14               8983
# 15               1050
# 16              10500
# 17              13541
# 18              14840
# 19               1150
# 20               1776
# 21               1328
# 22                692
# 23               1595
# 24               1606

# %%
#finding null values
df_dropped = df_short.dropna()
df_dropped.isnull().sum()
# Out:
# Food                          0
# Nutrition Value (per 100g)    0
# Quantity                      0
# Originated From               0
# Calories                      0
# Protein (g)                   0
# Fibre (g)                     0
# Vitamin C (mg)                0
# Antioxidant Score             0
# dtype: int64

# %%
df.describe()
# Out:
#          Calories  Protein (g)  Fibre (g)  Vitamin C (mg)  Antioxidant Score
# count   98.000000    98.000000  98.000000       98.000000          98.000000
# mean    83.479592     4.361224   3.030612       20.493878        6107.459184
# std     75.609718     5.914331   3.375149       34.704710       18831.230553
# min      1.000000     0.000000   0.000000        0.000000           0.000000
# 25%     19.250000     0.825000   0.850000        0.125000         989.000000
# 50%     61.000000     1.600000   2.150000        5.750000        1540.000000
# 75%    135.500000     4.925000   3.500000       22.275000        4277.250000
# max    320.000000    22.700000  15.600000      190.000000      131420.000000

# %%
numcol=df_short.select_dtypes(include=[np.number])
numcol.corr()
# Out:
#                    Calories  Protein (g)  Fibre (g)  Vitamin C (mg)  \
# Calories           1.000000     0.531407   0.643124       -0.213774
# Protein (g)        0.531407     1.000000   0.103545       -0.192593
# Fibre (g)          0.643124     0.103545   1.000000        0.071265
# Vitamin C (mg)    -0.213774    -0.192593   0.071265        1.000000
# Antioxidant Score -0.213951    -0.208326  -0.083124       -0.114349
#
#                    Antioxidant Score
# Calories                   -0.213951
# Protein (g)                -0.208326
# Fibre (g)                  -0.083124
# Vitamin C (mg)             -0.114349
# Antioxidant Score           1.000000

# %%
# 1. Bar Chart: Distribution of Calories
def plot_bar_chart_calories(df):
    plt.figure(figsize=(10, 4))
    plt.bar(df_short['Food'],df_short['Calories'], color='skyblue', edgecolor='black')
    plt.title("Distribution of Caloric Content")
    plt.xlabel("Food")
    plt.ylabel("Caloric content")
    plt.xticks(rotation=90)
    plt.show()
plot_bar_chart_calories(df)

# %%
# Data from the dataset
df_short=df_short.head(10)
foods=df_short['Food']
protein=df_short['Protein (g)']
#print(foods)
def plot_pie_chart(protein, labels, title):

    plt.figure(figsize=(8, 8))
    plt.pie(protein, labels=labels, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
    plt.title(title)
    plt.show()

# Plotting the pie chart for Total Protein Distribution by Food
plot_pie_chart(protein, foods, "Total Protein Distribution by Food")

# %%
# 2. Scatter Plot: Calories vs fibre
def plot_scatter_calories_fibre(df):
    df = df.head(20)
    plt.figure(figsize=(8,4))
    plt.scatter(df['Calories'], df['Fibre (g)'], color='purple', alpha=0.7)
    plt.title("Calories vs fibre")
    plt.xlabel("Calories")
    plt.ylabel("fibre (g)")
    plt.show()
plot_scatter_calories_fibre(df)

# %%
def plot_heatmap(df):
    df=df.head(25)
    numcol=df.select_dtypes(include=[np.number])
    hmap=numcol.corr()
  
    plt.figure(figsize=(8,6))
    sns.heatmap(hmap,annot=True,cmap='Spectral',linewidth=0.5)
    plt.title('Correlation')
    plt.subplots_adjust(left=0.2,right=0.9,top=0.50,bottom=0.1)
    plt.show()
plot_heatmap(df)
